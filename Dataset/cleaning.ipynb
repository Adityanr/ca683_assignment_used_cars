# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('autos.csv')

# %%
df
# Out:
#          index          dateCrawled  \
# 0            0  2016-03-24 11:52:17
# 1            1  2016-03-24 10:58:45
# 2            2  2016-03-14 12:52:21
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# ...        ...                  ...
# 371523  371523  2016-03-14 17:48:27
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371526  371526  2016-03-20 19:41:08
# 371527  371527  2016-03-07 19:39:19
#
#                                                 name  seller offerType  price  \
# 0                                         Golf_3_1.6  privat   Angebot    480
# 1                               A5_Sportback_2.7_Tdi  privat   Angebot  18300
# 2                     Jeep_Grand_Cherokee_"Overland"  privat   Angebot   9800
# 3                                 GOLF_4_1_4__3TÜRER  privat   Angebot   1500
# 4                     Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot   3600
# ...

# %%
# Remove any columns that have more than 50% of missing values
df = df.loc[:, df.isnull().mean() < 0.5]

# Drop any rows that have missing values
df = df.dropna()
df
# Out:
#          index          dateCrawled  \
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# 5            5  2016-04-04 17:36:23
# 6            6  2016-04-01 20:48:51
# 7            7  2016-03-21 18:54:38
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371521  371521  2016-03-27 20:36:20
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371527  371527  2016-03-07 19:39:19
#
#                                                      name  seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# 6                             Peugeot_206_CC_110_Platinum  privat   Angebot
# 7                            VW_Derby_Bj_80__Scheunenfund  privat   Angebot
# ...

# %%
# Define a mapping of German values to English values
german_to_english = {
    'privat': 'private',
    'gewerblich': 'commercial',
    'Angebot': 'offer',
    'Gesuch': 'request',
    'limousine': 'sedan',
    'kleinwagen': 'compact car',
    'kombi': 'station wagon',
    'cabrio': 'convertible',
    'andere': 'other',
    'manuell': 'manual',
    'automatik': 'automatic',
    'benzin': 'gasoline',
    'diesel': 'diesel',
    'cng': 'natural gas',
    'lpg': 'liquefied petroleum gas',
    'notrepaired': 'not repaired',
    'ja': 'yes',
    'nein': 'no'
}

# Convert the specified columns from German to English
df['seller'] = df['seller'].map(german_to_english)
df['offerType'] = df['offerType'].map(german_to_english)
df['vehicleType'] = df['vehicleType'].map(german_to_english)
df['gearbox'] = df['gearbox'].map(german_to_english)
df['model'] = df['model'].map(german_to_english)
df['fuelType'] = df['fuelType'].map(german_to_english)
df['notRepairedDamage'] = df['notRepairedDamage'].map(german_to_english)

# %%
df
# Out:
#          index          dateCrawled  \
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# 5            5  2016-04-04 17:36:23
# 6            6  2016-04-01 20:48:51
# 7            7  2016-03-21 18:54:38
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371521  371521  2016-03-27 20:36:20
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371527  371527  2016-03-07 19:39:19
#
#                                                      name   seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  private     offer
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  private     offer
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  private     offer
# 6                             Peugeot_206_CC_110_Platinum  private     offer
# 7                            VW_Derby_Bj_80__Scheunenfund  private     offer
# ...

# %%
# Convert the Mileage, Power, Engine_Size, and Price columns to numeric types
df['kilometer'] = pd.to_numeric(df['kilometer'].replace('[^0-9]', ''))
df['powerPS'] = pd.to_numeric(df['powerPS'].replace('[^0-9]', ''))
# df['Engine_Size'] = pd.to_numeric(df['Engine_Size'].str.replace('[^0-9]', ''))
df['price'] = pd.to_numeric(df['price'].replace('[^0-9]', ''))

# %%
df
# Out:
#          index          dateCrawled  \
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# 5            5  2016-04-04 17:36:23
# 6            6  2016-04-01 20:48:51
# 7            7  2016-03-21 18:54:38
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371521  371521  2016-03-27 20:36:20
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371527  371527  2016-03-07 19:39:19
#
#                                                      name   seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  private     offer
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  private     offer
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  private     offer
# 6                             Peugeot_206_CC_110_Platinum  private     offer
# 7                            VW_Derby_Bj_80__Scheunenfund  private     offer
# ...

# %%
# Remove any rows where the Registration_Year is earlier than 1980 or later than 2021
df = df[(df['yearOfRegistration'] >= 1980) & (df['yearOfRegistration'] <= 2021)]

# %%
df = df.dropna()
# Out:
#          index          dateCrawled  \
# 3            3  2016-03-17 16:54:04
# 4            4  2016-03-31 17:25:20
# 5            5  2016-04-04 17:36:23
# 6            6  2016-04-01 20:48:51
# 7            7  2016-03-21 18:54:38
# ...        ...                  ...
# 371520  371520  2016-03-19 19:53:49
# 371521  371521  2016-03-27 20:36:20
# 371524  371524  2016-03-05 19:56:21
# 371525  371525  2016-03-19 18:57:12
# 371527  371527  2016-03-07 19:39:19
#
#                                                      name   seller offerType  \
# 3                                      GOLF_4_1_4__3TÜRER  private     offer
# 4                          Skoda_Fabia_1.4_TDI_PD_Classic  private     offer
# 5       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  private     offer
# 6                             Peugeot_206_CC_110_Platinum  private     offer
# 7                            VW_Derby_Bj_80__Scheunenfund  private     offer
# ...

# %%
df.to_csv('cleaned_used_cars.csv', index=False)
